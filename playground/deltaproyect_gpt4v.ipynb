# %%
import base64

# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "certificado_ayuda_económica.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)

# %%
import urllib.request
from io import BytesIO 

image_url = 'http://t1.gstatic.com/licensed-image?q=tbn:ANd9GcSRRNRPJ9V2ta2gQgvdmd1dJBuHw3OOVSopx_cn55UZS3gp3yanw1tW_WSYOQVDSFpSuo-f-s1jnQN9rPHRNCQ'

with urllib.request.urlopen(image_url) as url:
    img = Image.open(BytesIO(url.read()))

img_resized = img.resize((200, 200))

# %%
print(base64_image)
# Out:
# ...

# %%
base64_image = "..."

# %%
import os # Included to Python
from openai import OpenAI # OpenAI official Python package
# from IPython.display import Audio # Included to Python

os.environ["OPENAI_API_KEY"] = "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"

client = OpenAI(
    api_key=os.getenv("openaikey"))

# %%
response = client.chat.completions.create(
    model="gpt-4-vision-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": """
                    ¿Puedes transcribir la siguiente imagen en un formato JSON correctamente formateado, enfocándote en cada campo y asegurándote de que sea exactamente lo que dice la imagen? Asegúrate de que el JSON esté correctamente formateado según los estándares para este formato. Solo dame el JSON como respuesta para copiarlo y pegarlo para su posterior uso.
                    """
                },
                {
                    "type": "image_url",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
    max_tokens=2048,
)

# %%
print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "DEPARTAMENTO_RECURSOS_HUMANOS": "DEPARTAMENTO BIENESTAR SOCIAL",
#   "PRO_DRH_21": "",
#   "ANEXO_C": {
#     "CERTIFICADO_DE_AYUDA_ECONOMICA_N": ""
#   },
#   "CONTENIDO": {
#     "ENCABEZADO": "EL/LA JEFE/A O ENCARGADO/A DEL DEPARTAMENTO DE BIENESTAR SOCIAL DE LA DIRECCIÓN GENERAL DE AERONÁUTICA CIVIL QUE SUSCRIBE, CERTIFICA QUE HA OTORGADO UNA AYUDA ECONÓMICA AL FUNCIONARIO QUE A CONTINUACIÓN SE INDICA POR EL MONTO QUE SE INDICA:",
#     "IDENTIFICACION_DEL_SOLICITANTE": {
#       "APELLIDO_PATERNO": "Molina",
#       "APELLIDO_MATERNO": "Pérez",
#       "NOMBRES": "Sebastián Alfonso",
#       "RUT": "17981719",
#       "ESPECIALIDAD_DEL_FUNCIONARIO": "Mecánico",
#       "AÑOS_DE_SERVICIOS": "",
#       "NOMBRE_DE_LA_UNIDAD": "Operario de Planta",
#       "TELEFONO": "+5697468179",
#       "ESCRIBIR_EL_MONTO_EN_PALABRAS": "Un Millón de pesos chilenos"
#     },
#     "PIE_DE_PAGINA": "PREVIO ESTUDIO DE LA SOLICITUD PRESENTADA Y DEL INFORME SOCIAL DEL DEPARTAMENTO BIENESTAR SOCIAL."
#   },
#   "FIRMAS": {
#     "FIRMA_FUNCIONARIO_A": "",
#     "ASISTENTE_SOCIAL_FIRMA_Y_TIMBRE": "",
#     "JEFE_A_ENCARGADO_A_DEPTO_BIENESTAR_SOCIAL": ""
#   },
#   "PIE_DE_DOCUMENTO": "18",
#   "CODIGO_DOCUMENTO": "Enm.2 ED.3/JUL 2020"
# }
# ```

# %%
from PIL import Image
from IPython.display import display

# %%
print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "DEPARTAMENTO_RECURSOS_HUMANOS": "DEPARTAMENTO BIENESTAR SOCIAL",
#   "PRO_DRH": 21,
#   "ANEXO_C": {
#     "CERTIFICADO_DE_AYUDA_ECONOMICA_N": "",
#     "DECLARACION": "EL/LA JEFE/A O ENCARGADO/A DEL DEPARTAMENTO DE BIENESTAR SOCIAL DE LA DIRECCIÓN GENERAL DE AERONAUTICA CIVIL QUE SUSCRIBE, CERTIFICA QUE HA OTORGADO UNA AYUDA ECONÓMICA AL FUNCIONARIO QUE A CONTINUACIÓN SE INDICA POR EL MONTO QUE SE INDICA:"
#   },
#   "IDENTIFICACION_DEL_SOLICITANTE": {
#     "APELLIDO_PATERNO": "Molina",
#     "APELLIDO_MATERNO": "Pérez",
#     "NOMBRES": "Sebastían Alfonso",
#     "RUT": "17687519-k",
#     "ESPECIALIDAD_DEL_FUNCIONARIO": "Mecánico",
#     "AÑOS_DE_SERVICIOS": "",
#     "NOMBRE_DE_LA_UNIDAD": "Operario de Planta",
#     "TELEFONO": "+5697648179",
#     "ESCRIBIR_EL_MONTO_EN_PALABRAS": "Un Millón de pesos chilenos"
#   },
#   "PREVIO_ESTUDIO": "PREVIO ESTUDIO DE LA SOLICITUD PRESENTADA Y DEL INFORME SOCIAL DEL DEPARTAMENTO BIENESTAR SOCIAL.",
#   "FIRMA_FUNCIONARIO_A": "",
#   "ASISTENTE_SOCIAL_FIRMA_Y_TIMBRE": "",
#   "JEFA_O_ENCARGADO_A": "DEPTO. BIENESTAR SOCIAL",
#   "PAGINA": 18,
#   "ENMIENDA": "Enm.2 ED.3/JUL 2020"
# }
# ```

# %%
import json
respuesta_chatbot = response.choices[0].message.content
formato_respuesta_chatbot = respuesta_chatbot.replace("```", "").replace("json", "").strip()
diccionario_respuesta = json.loads(formato_respuesta_chatbot)
print(diccionario_respuesta)
# Out:
# {'DEPARTAMENTO_RECURSOS_HUMANOS': 'DEPARTAMENTO BIENESTAR SOCIAL', 'PRO_DRH_21': '', 'ANEXO_C': {'CERTIFICADO_DE_AYUDA_ECONOMICA_N': ''}, 'CONTENIDO': {'ENCABEZADO': 'EL/LA JEFE/A O ENCARGADO/A DEL DEPARTAMENTO DE BIENESTAR SOCIAL DE LA DIRECCIÓN GENERAL DE AERONÁUTICA CIVIL QUE SUSCRIBE, CERTIFICA QUE HA OTORGADO UNA AYUDA ECONÓMICA AL FUNCIONARIO QUE A CONTINUACIÓN SE INDICA POR EL MONTO QUE SE INDICA:', 'IDENTIFICACION_DEL_SOLICITANTE': {'APELLIDO_PATERNO': 'Molina', 'APELLIDO_MATERNO': 'Pérez', 'NOMBRES': 'Sebastián Alfonso', 'RUT': '17981719', 'ESPECIALIDAD_DEL_FUNCIONARIO': 'Mecánico', 'AÑOS_DE_SERVICIOS': '', 'NOMBRE_DE_LA_UNIDAD': 'Operario de Planta', 'TELEFONO': '+5697468179', 'ESCRIBIR_EL_MONTO_EN_PALABRAS': 'Un Millón de pesos chilenos'}, 'PIE_DE_PAGINA': 'PREVIO ESTUDIO DE LA SOLICITUD PRESENTADA Y DEL INFORME SOCIAL DEL DEPARTAMENTO BIENESTAR SOCIAL.'}, 'FIRMAS': {'FIRMA_FUNCIONARIO_A': '', 'ASISTENTE_SOCIAL_FIRMA_Y_TIMBRE': '', 'JEFE_A_ENCARGADO_A_DEPTO_BIENESTAR_SOCIAL': ''}, 'PIE_DE_DOCUMENTO': '18', 'CODIGO_DOCUMENTO': 'Enm.2 ED.3/JUL 2020'}
